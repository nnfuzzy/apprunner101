# %% [markdown]
# # Imports

# %%
import dateutil
import json
import os
import requests
import pandas as pd
import numpy as np
import xlrd
from fbprophet import Prophet
import matplotlib.pyplot as plt

# %%
import datetime
from datetime import timedelta

# %%
# %config Completer.use_jedi = False
# %reload_ext lab_black

# %% [markdown]
# # Tracked bicyles in Berlin

# %%
xl = pd.ExcelFile("gesamtdatei_stundenwerte_2012-2019.xlsx", engine="openpyxl")
sheet_names = xl.sheet_names  # see all sheet names
list(enumerate(sheet_names))
# Out:
# [(0, 'Hinweise'),
#  (1, 'Legende'),
#  (2, 'Standortdaten'),
#  (3, 'Jahresdatei 2012'),
#  (4, 'Jahresdatei 2013'),
#  (5, 'Jahresdatei 2014'),
#  (6, 'Jahresdatei 2015'),
#  (7, 'Jahresdatei 2016'),
#  (8, 'Jahresdatei 2017'),
#  (9, 'Jahresdatei 2018'),
#  (10, 'Jahresdatei 2019')]

# %% [markdown]
# ## Prepare data from excel into meaningful data frame

# %%
rs = []
for i in range(7, 10 + 1):
    tmpdf = xl.parse(sheet_names[i])
    tmpdf.columns = [c.split(" ")[0] for c in tmpdf.columns]
    tmpdf = tmpdf.rename({"Zählstelle": "dt"}, axis=1)
    tmpdf = tmpdf.melt(
        id_vars="dt",
        value_vars=tmpdf.columns.tolist()[1:],
        var_name="place",
        value_name="cnt",
    )
    tmpdf = tmpdf.dropna(subset=["dt"])
    tmpdf = tmpdf.fillna(0)
    tmpdf.set_index(["dt", "place"])
    rs.append(tmpdf)

# %%
df = pd.concat(rs)

# %%
place_mapping = (
    xl.parse(sheet_names[2]).dropna().rename({"Zählstelle": "place"}, axis=1)
)

# %%
df = df.merge(place_mapping, on="place")

# %%
df.columns = [
    "dt",
    "place",
    "cnt",
    "place_description",
    "lat",
    "lon",
    "dt_installation",
]

# %%
df[df.dt >= "2016-01-01"]
# Out:
#                         dt        place   cnt     place_description  \
# 0      2016-01-01 00:00:00  02-MI-JAN-N   9.0  Jannowitzbrücke Nord
# 1      2016-01-01 01:00:00  02-MI-JAN-N  26.0  Jannowitzbrücke Nord
# 2      2016-01-01 02:00:00  02-MI-JAN-N  23.0  Jannowitzbrücke Nord
# 3      2016-01-01 03:00:00  02-MI-JAN-N  28.0  Jannowitzbrücke Nord
# 4      2016-01-01 04:00:00  02-MI-JAN-N  21.0  Jannowitzbrücke Nord
# ...                    ...          ...   ...                   ...
# 841507 2019-12-31 19:00:00    27-RE-MAR  13.0            Markstraße
# 841508 2019-12-31 20:00:00    27-RE-MAR   6.0            Markstraße
# 841509 2019-12-31 21:00:00    27-RE-MAR  11.0            Markstraße
# 841510 2019-12-31 22:00:00    27-RE-MAR   2.0            Markstraße
# 841511 2019-12-31 23:00:00    27-RE-MAR   7.0            Markstraße
#
#               lat        lon dt_installation
# 0       52.513932  13.417835      2015-04-01
# 1       52.513932  13.417835      2015-04-01
# 2       52.513932  13.417835      2015-04-01
# 3       52.513932  13.417835      2015-04-01
# 4       52.513932  13.417835      2015-04-01
# ...           ...        ...             ...
# 841507  52.558190  13.364944      2015-05-01
# 841508  52.558190  13.364944      2015-05-01
# 841509  52.558190  13.364944      2015-05-01
# 841510  52.558190  13.364944      2015-05-01
# 841511  52.558190  13.364944      2015-05-01
#
# [841512 rows x 7 columns]

# %% [markdown]
# ## Add weather data

# %% [markdown]
# ### Calculate costs for weather data

# %%
price_params = {"month": 12, "years": 4, "days": 31, "hours": 24, "price": 0.0001}
cost_calculation = f"$ {np.prod(list(price_params.values()))}"
cost_calculation
# Out:
# '$ 3.5712'

# %% [markdown]
# ### chunking in terms of hourly is necessary, beacuse it's possible to collect 25k records in a request only

# %%
def collect_weather_data(key, lat, lon, start_dt, end_dt, hourly=False):
    dt_month_list = [
        s.strftime("%Y-%-m-%d")
        for s in list(
            dateutil.rrule.rrule(
                dateutil.rrule.MONTHLY,
                dtstart=datetime.date(*start_dt),
                until=datetime.date(*end_dt) + timedelta(days=30),
            )
        )
    ]
    weather_data = []
    for i in range(0, len(dt_month_list) - 1):
        print(i)
        tmp_start_dt = dt_month_list[i]
        tmp_end_dt = datetime.datetime.strftime(
            datetime.datetime.strptime(dt_month_list[i + 1], "%Y-%m-%d")
            - datetime.timedelta(days=1),
            "%Y-%-m-%d",
        )

        if hourly:
            url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lon}/{tmp_start_dt}/{tmp_end_dt}?unitGroup=metric&key={key}&include=obs,hours"
        else:
            url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lon}/{tmp_start_dt}/{tmp_end_dt}?unitGroup=metric&key={key}&include=obs"
        resp = requests.get(url)
        res_json = resp.json()
        for tmp in res_json["days"]:
            day = tmp["datetime"]
            if hourly:
                df_tmp = pd.DataFrame(tmp["hours"])
            else:
                df_tmp = pd.DataFrame(tmp)
            df_tmp.insert(loc=0, column="day", value=day)
            weather_data.append(df_tmp)
    df_weather = pd.concat(weather_data)
    return df_weather

# %% [markdown]
# ### Apply chunked weather data collection

# %%
weather_api_params = dict(
    key=os.environ["WEATHER_DATA_SECRET"],
    lat="52.513932",
    lon="13.417835",
    start_dt=(2016, 1, 1),
    end_dt=(2020, 1, 1),
    hourly=False,
)

# %%
# df_weather = collect_weather_data(**weather_api_params)
# df_weather.to_csv("weather_data_daily.csv", sep=";", index=None)

# %%
df_weather = pd.read_csv("weather_data_daily.csv", sep=";", index_col=None)

# %%
df_weather["day"] = pd.to_datetime(df_weather["day"])
df_weather["hours"] = df_weather.apply(lambda x: int(str(x.datetime)[0:2]), axis=1)
df_weather["dt"] = df_weather.apply(
    lambda x: x.day + pd.Timedelta(hours=x.hours), axis=1
)

# %%
df_weather.head()
# Out:
#          day    datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0 2016-01-01  2016-01-01     1451602800      2.7      1.0   1.5           1.8
# 1 2016-01-01  2016-01-01     1451602800      2.7      1.0   1.5           1.8
# 2 2016-01-01  2016-01-01     1451602800      2.7      1.0   1.5           1.8
# 3 2016-01-01  2016-01-01     1451602800      2.7      1.0   1.5           1.8
# 4 2016-01-02  2016-01-02     1451689200      1.0     -7.1  -3.3          -1.4
#
#    feelslikemin  feelslike  dew  ...  sunsetEpoch  moonphase  \
# 0          -1.5        0.2  1.2  ...   1451660532       0.72
# 1          -1.5        0.2  1.2  ...   1451660532       0.72
# 2          -1.5        0.2  1.2  ...   1451660532       0.72
# 3          -1.5        0.2  1.2  ...   1451660532       0.72
# 4         -16.0       -9.6 -5.6  ...   1451746997       0.77
#
#          conditions                        description               icon  \
# 0  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 1  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 2  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 3  Partially cloudy  Partly cloudy throughout the day.  partly-cloudy-day
# 4          Overcast   Cloudy skies throughout the day.               wind
#
#       stations  source  tzoffset  hours                  dt
# 0  10382099999     obs       NaN     20 2016-01-01 20:00:00
# 1  10385099999     obs       NaN     20 2016-01-01 20:00:00
# 2         EDDB     obs       NaN     20 2016-01-01 20:00:00
# 3         EDDT     obs       NaN     20 2016-01-01 20:00:00
# 4  10382099999     obs       NaN     20 2016-01-02 20:00:00
#
# [5 rows x 39 columns]

# %%
df_weather.columns
# Out:
# Index(['day', 'datetime', 'datetimeEpoch', 'tempmax', 'tempmin', 'temp',
#        'feelslikemax', 'feelslikemin', 'feelslike', 'dew', 'humidity',
#        'precip', 'precipprob', 'precipcover', 'preciptype', 'snow',
#        'snowdepth', 'windgust', 'windspeed', 'winddir', 'pressure',
#        'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 'uvindex',
#        'sunrise', 'sunriseEpoch', 'sunset', 'sunsetEpoch', 'moonphase',
#        'conditions', 'description', 'icon', 'stations', 'source', 'tzoffset',
#        'hours', 'dt'],
#       dtype='object')

# %%
df["day"] = df["dt"].dt.date

# %%
df_day_agg = df.groupby(["day", "place_description"], as_index=False)["cnt"].sum()
df_day_agg["day"] = pd.to_datetime(df_day_agg["day"])

# %%
df_weather_cleaned = (
    df_weather[["day", "tempmax", "tempmin", "humidity", "cloudcover", "windspeed"]]
    .drop_duplicates(subset="day")
    .fillna(0)
)
df_weather_cleaned.head(3)
# Out:
#          day  tempmax  tempmin  humidity  cloudcover  windspeed
# 0 2016-01-01      2.7      1.0     97.73        86.8       11.2
# 4 2016-01-02      1.0     -7.1     85.15        91.8       32.9
# 8 2016-01-03     -7.3    -11.3     74.78        44.2       29.8

# %%
dfm = df_day_agg.merge(df_weather_cleaned, on="day")
dfm = dfm.rename({"day": "dt"}, axis=1)
dfm.to_csv(
    "ts_bicycle_and_weather_berlin_day.csv.gz",
    sep="|",
    index=None,
    encoding="utf8",
    compression="gzip",
)

# %%
dfm[dfm.cnt > 0].head(10).reset_index(drop=True)
# Out:
#           dt       place_description    cnt  tempmax  tempmin  humidity  \
# 0 2016-01-01          Alberichstraße   91.0      2.7      1.0     97.73
# 1 2016-01-01     Invalidenstraße Ost  233.0      2.7      1.0     97.73
# 2 2016-01-01    Invalidenstraße West  314.0      2.7      1.0     97.73
# 3 2016-01-01    Jannowitzbrücke Nord  530.0      2.7      1.0     97.73
# 4 2016-01-01     Jannowitzbrücke Süd  420.0      2.7      1.0     97.73
# 5 2016-01-01              Markstraße  165.0      2.7      1.0     97.73
# 6 2016-01-01        Monumentenstraße  566.0      2.7      1.0     97.73
# 7 2016-01-01      Oberbaumbrücke Ost  844.0      2.7      1.0     97.73
# 8 2016-01-01     Oberbaumbrücke West  776.0      2.7      1.0     97.73
# 9 2016-01-01  Paul-und-Paula-Uferweg  629.0      2.7      1.0     97.73
#
#    cloudcover  windspeed
# 0        86.8       11.2
# 1        86.8       11.2
# 2        86.8       11.2
# 3        86.8       11.2
# 4        86.8       11.2
# 5        86.8       11.2
# 6        86.8       11.2
# 7        86.8       11.2
# 8        86.8       11.2
# 9        86.8       11.2

# %%
pd.read_csv("weather_data_hourly.csv", sep=";", index_col=None)
# Out:
#               day  datetime  datetimeEpoch  temp  feelslike  humidity  dew  \
# 0      2016-01-01  00:00:00     1451602800   1.7        0.3     94.79  1.0
# 1      2016-01-01  01:00:00     1451606400   1.7        1.7    100.00  1.7
# 2      2016-01-01  02:00:00     1451610000   2.6        1.1     93.97  1.7
# 3      2016-01-01  03:00:00     1451613600   2.7        1.1     94.83  2.0
# 4      2016-01-01  04:00:00     1451617200   2.0        0.7     94.80  1.2
# ...           ...       ...            ...   ...        ...       ...  ...
# 35059  2019-12-31  19:00:00     1577815200   5.4        2.0     77.60  1.8
# 35060  2019-12-31  20:00:00     1577818800   5.0        1.4     78.68  1.6
# 35061  2019-12-31  21:00:00     1577822400   4.1        0.3     81.01  1.1
# 35062  2019-12-31  22:00:00     1577826000   3.7        0.2     83.92  1.3
# 35063  2019-12-31  23:00:00     1577829600   3.7        0.4     82.74  1.1
#
#        precip  precipprob  snow  ...  visibility  cloudcover  solarradiation  \
# 0         NaN         NaN   0.0  ...         3.4        90.4             NaN
# 1         NaN         NaN   0.0  ...         0.6        97.2             NaN
# 2         NaN         NaN   0.0  ...         0.5        64.0             NaN
# 3         NaN         NaN   0.0  ...         1.3        97.2             NaN
# 4         NaN         NaN   0.0  ...         1.5        97.2             NaN
# ...       ...         ...   ...  ...         ...         ...             ...
# 35059     0.0         NaN   0.0  ...        42.2         NaN             NaN
# 35060     0.0         NaN   0.0  ...        38.1         NaN             NaN
# 35061     0.0         NaN   0.0  ...        34.1         NaN             NaN
# 35062     0.0         NaN   0.0  ...        29.7         NaN             NaN
# 35063     0.0         NaN   0.0  ...        28.8         NaN             NaN
#
#        solarenergy  uvindex        conditions         icon  \
# 0              NaN      0.0          Overcast       cloudy
# 1              NaN      0.0          Overcast          fog
# 2              NaN      0.0  Partially cloudy          fog
# 3              NaN      0.0          Overcast       cloudy
# 4              NaN      0.0          Overcast       cloudy
# ...            ...      ...               ...          ...
# 35059          NaN      0.0             Clear  clear-night
# 35060          NaN      0.0             Clear  clear-night
# 35061          NaN      0.0             Clear  clear-night
# 35062          NaN      0.0             Clear  clear-night
# 35063          NaN      0.0             Clear  clear-night
#
#                                                 stations  source  tzoffset
# 0         ['10382099999', '10385099999', 'EDDB', 'EDDT']     obs       NaN
# 1         ['10382099999', '10385099999', 'EDDB', 'EDDT']     obs       NaN
# 2         ['10382099999', '10385099999', 'EDDB', 'EDDT']     obs       NaN
# 3         ['10382099999', '10385099999', 'EDDB', 'EDDT']     obs       NaN
# 4         ['10382099999', '10385099999', 'EDDB', 'EDDT']     obs       NaN
# ...                                                  ...     ...       ...
# 35059  ['07389', '03376', '03987', '05825', '03015', ...     obs       NaN
# 35060  ['07389', '03376', '03987', '05825', '03015', ...     obs       NaN
# 35061  ['07389', '03376', '03987', '05825', '03015', ...     obs       NaN
# 35062  ['07389', '03376', '03987', '05825', '03015', ...     obs       NaN
# 35063  ['07389', '03376', '03987', '05825', '03015', ...     obs       NaN
#
# [35064 rows x 26 columns]
